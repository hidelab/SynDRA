# %%
# load /Users/tolgacorbaci/Desktop/Code/synonyms/input/File_2_Drugname_library_527D.txt
# -*- coding: utf-8 -*-
import sys
import os
import pandas as pd

file_path = '/Users/tolgacorbaci/Desktop/Code/synonyms/input/File_2_Drugname_library_527D.txt'
if not os.path.exists(file_path):
    print(f"File not found: {file_path}")
    sys.exit(1)

df = pd.read_csv(file_path, sep="\t", dtype=str)

# %%
df
# Out:
#                   drug                     InChiKey  \
# 0           Nelarabine  IXOXBSCIXZEQEQ-UHTZMRCNSA-N
# 1           Decitabine  XAUDJQYHKZQPEU-KVQBGUIXSA-N
# 2             Olaparib  FDLYAMZZIXQODN-UHFFFAOYSA-N
# 3           Vorinostat  WAEXFXRVDQXREF-UHFFFAOYSA-N
# 4    Aminoglutethimide  ROBVIMPUHSLWNV-UHFFFAOYSA-N
# ..                 ...                          ...
# 522            TAK-530  VWMJHAFYPMOMGF-ZCFIWIBFSA-N
# 523           CPI-0610  GCWIQUVXWZWCLE-INIZCTEOSA-N
# 524      Disulfiram+Cu  AUZONCFQVSMFAP-UHFFFAOYSA-N
# 525            Erastin  BKQFRNYHFIQEKN-UHFFFAOYSA-N
# 526               RSL3  TXJZRSRTYPUYRW-NQIIRXRSSA-N
#
#                                               synonyms drugclass
# 0                          ARRANON;ATRIANCE;NELARABINE     chemo
# 1            DACOGEN;5-AZA-2'-DEOXYCYTIDINE;DECITABINE  targeted
# 2                 AZD2281;OLAPARIB;LYNPARZA;KU-0059436  targeted
# 3                      VORINOSTAT;ZOLINZA;SAHA;MK-0683  targeted
# 4                           AMINOGLUTETHIMIDE;CYTADREN  targeted
# ..                                                 ...       ...
# 522                  MLN-2480;BIIB-024;TAK-530;TAK-580  targeted
# 523                                           CPI-0610  targeted
# 524  DISULFIRAM+CU;DISULFIRAM;ANTABUSE;DISULFIRAM (...  targeted
# 525                                            ERASTIN  targeted
# 526                                               RSL3  targeted
#
# [527 rows x 4 columns]

# %%
#append drug column string to synonyms column sep ;
df['synonyms'] = df['drug'] + '; ' + df['synonyms']
# explode df on synonyms column separating by ";" and add it as a new row for each synonym
df['synonyms'] = df['synonyms'].str.split(';')
df = df.explode('synonyms')
# remove leading and trailing spaces from synonyms
df['synonyms'] = df['synonyms'].str.strip()
# remove empty synonyms
df = df[df['synonyms'] != '']
# reset index
df['synonyms'] = df['synonyms'].str.lower().str.strip()
df['drug'] = df['drug'].str.lower().str.strip()


df.reset_index(drop=True, inplace=True)

#drop duplicates subset synonyms
df.drop_duplicates(subset=['synonyms'], inplace=True)
# Display the first few rows of the DataFrame
df.head()
# Out:
#          drug                     InChiKey    synonyms drugclass
# 0  nelarabine  IXOXBSCIXZEQEQ-UHTZMRCNSA-N  nelarabine     chemo
# 1  nelarabine  IXOXBSCIXZEQEQ-UHTZMRCNSA-N     arranon     chemo
# 2  nelarabine  IXOXBSCIXZEQEQ-UHTZMRCNSA-N    atriance     chemo
# 4  decitabine  XAUDJQYHKZQPEU-KVQBGUIXSA-N  decitabine  targeted
# 5  decitabine  XAUDJQYHKZQPEU-KVQBGUIXSA-N     dacogen  targeted

# %%
df
# Out:
#                drug                     InChiKey              synonyms  \
# 0        nelarabine  IXOXBSCIXZEQEQ-UHTZMRCNSA-N            nelarabine
# 1        nelarabine  IXOXBSCIXZEQEQ-UHTZMRCNSA-N               arranon
# 2        nelarabine  IXOXBSCIXZEQEQ-UHTZMRCNSA-N              atriance
# 4        decitabine  XAUDJQYHKZQPEU-KVQBGUIXSA-N            decitabine
# 5        decitabine  XAUDJQYHKZQPEU-KVQBGUIXSA-N               dacogen
# ...             ...                          ...                   ...
# 1750  disulfiram+cu  AUZONCFQVSMFAP-UHFFFAOYSA-N            disulfiram
# 1751  disulfiram+cu  AUZONCFQVSMFAP-UHFFFAOYSA-N              antabuse
# 1752  disulfiram+cu  AUZONCFQVSMFAP-UHFFFAOYSA-N  disulfiram (+cu 2:1)
# 1753        erastin  BKQFRNYHFIQEKN-UHFFFAOYSA-N               erastin
# 1755           rsl3  TXJZRSRTYPUYRW-NQIIRXRSSA-N                  rsl3
#
#      drugclass
# 0        chemo
# 1        chemo
# 2        chemo
# 4     targeted
# 5     targeted
# ...        ...
# 1750  targeted
# 1751  targeted
# 1752  targeted
# 1753  targeted
# 1755  targeted
#
# [1227 rows x 4 columns]

# %%
# load synonyms /Users/tolgacorbaci/Desktop/Code/synonyms/output/merged_200K_drug_synonyms.csv
synonyms_file_path = '/Users/tolgacorbaci/Desktop/Code/synonyms/output/merged_200K_drug_synonyms.csv'
if not os.path.exists(synonyms_file_path):
    print(f"Synonyms file not found: {synonyms_file_path}")
    sys.exit(1)
synonyms_df = pd.read_csv(synonyms_file_path, dtype=str)

# %%
synonyms_df
# Out:
#         BROAD_drug_ID                                           synonyms  \
# 0       BRD-K52256627                                      chlorhexidine
# 1       BRD-K52256627                        chlorhexidine, combinations
# 2       BRD-K52256627  1,1'-hexamethylenebis[5-(4-chlorophenyl)biguan...
# 3       BRD-K52256627  1n-[6-[4-chloroanilino(imino)methylamino(imino...
# 4       BRD-K52256627                               biguanide derivative
# ...               ...                                                ...
# 193216  BRD-K63068307  2-(difluoromethyl)-1-[4,6-di(4-morpholinyl)-1,...
# 193217  BRD-K63068307  2-(difluoromethyl)-1-[4,6-di(morpholin-4-yl)-1...
# 193218  BRD-K63068307  4,4''-(6-(2-(difluoromethyl)-1h-benzo[d]imidaz...
# 193219  BRD-K63068307  4,4-(6-(2-(difluoromethyl)-1h-benzo[d]imidazol...
# 193220  BRD-K63068307                                                zs4
#
#        TTD_drug_ID PubChem_CID
# 0           D0V4GY   9552079.0
# 1           D0V4GY   9552079.0
# 2           D0V4GY   9552079.0
# 3           D0V4GY   9552079.0
# 4           D0V4GY   9552079.0
# ...            ...         ...
# 193216      D0O1LD  11647372.0
# 193217      D0O1LD  11647372.0
# 193218      D0O1LD  11647372.0
# 193219      D0O1LD  11647372.0
# 193220      D0O1LD  11647372.0
#
# [193221 rows x 4 columns]

# %%
#match df and synonyms_df on drug and synonym columns
#str lower and remove leading and trailing spaces from both columns
# match letter case insensitive
synonyms_df['synonyms'] = synonyms_df['synonyms'].str.lower().str.strip()
# merge df and synonyms_df on synonyms column
merged_df = pd.merge(df, synonyms_df, left_on='synonyms', right_on='synonyms', how='inner')

# %%
# str lower and remove leading and trailing spaces from drug column
merged_df['drug'] = merged_df['drug'].str.lower().str.strip()
#drop duplicates
merged_df = merged_df.drop_duplicates(subset=['drug', 'synonyms'])

# %%
merged_df # Display the first few rows of the merged DataFrame
# Out:
#               drug                     InChiKey    synonyms drugclass  \
# 0       nelarabine  IXOXBSCIXZEQEQ-UHTZMRCNSA-N  nelarabine     chemo
# 1       nelarabine  IXOXBSCIXZEQEQ-UHTZMRCNSA-N     arranon     chemo
# 2       nelarabine  IXOXBSCIXZEQEQ-UHTZMRCNSA-N    atriance     chemo
# 3       decitabine  XAUDJQYHKZQPEU-KVQBGUIXSA-N  decitabine  targeted
# 4       decitabine  XAUDJQYHKZQPEU-KVQBGUIXSA-N     dacogen  targeted
# ..             ...                          ...         ...       ...
# 835        mst-312  MIQUEZGHEJGPJB-UHFFFAOYSA-N     mst-312  targeted
# 837        tak-530  VWMJHAFYPMOMGF-ZCFIWIBFSA-N    mln-2480  targeted
# 838  disulfiram+cu  AUZONCFQVSMFAP-UHFFFAOYSA-N  disulfiram  targeted
# 839  disulfiram+cu  AUZONCFQVSMFAP-UHFFFAOYSA-N    antabuse  targeted
# 840        erastin  BKQFRNYHFIQEKN-UHFFFAOYSA-N     erastin  targeted
#
#      BROAD_drug_ID TTD_drug_ID PubChem_CID
# 0    BRD-K84466663      D0B8UJ   3011155.0
# 1    BRD-K84466663      D0B8UJ   3011155.0
# 2    BRD-K84466663      D0B8UJ   3011155.0
# 3    BRD-K79254416      D0X5XU    451668.0
# 4    BRD-K79254416      D0X5XU    451668.0
# ..             ...         ...         ...
# 835  BRD-K19894101         NaN         NaN
# 837  BRD-K43410529         NaN         NaN
# 838  BRD-K32744045      D0X5SD      3117.0
# 839  BRD-K32744045      D0X5SD      3117.0
# 840  BRD-A25004090         NaN  11214940.0
#
# [795 rows x 7 columns]

# %%
# get unique number of BROAD_drug_ID
unique_broad_drug_ids = merged_df['BROAD_drug_ID'].nunique()
print(f"Unique BROAD_drug_ID count: {unique_broad_drug_ids}")
# Out:
# Unique BROAD_drug_ID count: 354

# %%
# group merged_df by drug and aggregate the synonyms column, but keep the other columns as they are
merged_df2 = merged_df.groupby('BROAD_drug_ID').agg(lambda x: x.iloc[0] if x.name != 'synonyms' else '; '.join(x)).reset_index()
merged_df2
# Out:
#      BROAD_drug_ID           drug                     InChiKey  \
# 0    BRD-A06916187        cpi-613  ZYRLHJIMTROTBO-UHFFFAOYSA-N
# 1    BRD-A10188456  dexamethasone  UREBDLICKHMUKA-CXSFZGCWSA-N
# 2    BRD-A11706664    triciribine  HOGVTUZUJGHKPL-HTVVRFAVSA-N
# 3    BRD-A12409803      orteronel  OZPFIJIOIVJZMN-SFHVURJKSA-N
# 4    BRD-A12994259   pomalidomide  UVSMNLNDYGZFPF-UHFFFAOYSA-N
# ..             ...            ...                          ...
# 349  BRD-K99749624      linifanib  MPVGZUGXCQEXTM-UHFFFAOYSA-N
# 350  BRD-K99964838      bosutinib  UBPYILGKFZZVDX-UHFFFAOYSA-N
# 351  BRD-M43490210    oxaliplatin  ZROHGHOFXNOHSO-BNTLRKBRSA-L
# 352           C646           c646  HEKJYZZSCQBJGB-UHFFFAOYSA-N
# 353         CI-994   tacedinaline  VAZAPHZUAVEOMC-UHFFFAOYSA-N
#
#                                               synonyms drugclass TTD_drug_ID  \
# 0                                              cpi-613  targeted         NaN
# 1                      dexamethasone; decadron; dexpak  targeted      D0IT2G
# 2    nsc 154020; pentaazacentopthylene; tricyclic n...  targeted      D04GSV
# 3                                   orteronel; tak-700  targeted      D0X3OI
# 4                      pomalidomide; pomalyst; cc-4047  targeted      D0A3ZU
# ..                                                 ...       ...         ...
# 349               linifanib; al-39324; rg3635; abt-869  targeted      D0M9QZ
# 350                        bosutinib; bosulif; ski-606  targeted      D0OB0F
# 351                                        oxaliplatin     chemo      D0Y3ME
# 352                                               c646  targeted         NaN
# 353                                             ci-994  targeted         NaN
#
#     PubChem_CID
# 0           NaN
# 1      236702.0
# 2       65399.0
# 3           NaN
# 4      134780.0
# ..          ...
# 349  11485656.0
# 350   5328940.0
# 351   9887053.0
# 352         NaN
# 353         NaN
#
# [354 rows x 7 columns]

# %%
# check drug column for duplicates and print them
duplicates = merged_df2[merged_df2.duplicated(subset=['drug'], keep=False)]
if not duplicates.empty:
    print("Duplicates found in 'drug' column:")
    print(duplicates)
# Out:
# Duplicates found in 'drug' column:
#      BROAD_drug_ID          drug                     InChiKey  \
# 2    BRD-A11706664   triciribine  HOGVTUZUJGHKPL-HTVVRFAVSA-N
# 38   BRD-A83081521   finasteride  DBEPLOCGEIEOCV-WSBQPABSSA-N
# 60   BRD-K06926592     tretinoin  SHGAZHPCJJPHSC-YCNIQYBTSA-N
# 90   BRD-K16133773   abiraterone  GZOSMCIZMLWJML-VJLLXTKPSA-N
# 98   BRD-K17896185   finasteride  DBEPLOCGEIEOCV-WSBQPABSSA-N
# 119  BRD-K22429181     tretinoin  SHGAZHPCJJPHSC-YCNIQYBTSA-N
# 141  BRD-K30618791     docetaxel  ZDZOTLJHXYCWBA-JXHJHTFNSA-N
# 144  BRD-K31928526  azd1152-hqpa  QYZOGCMHVIGURT-UHFFFAOYSA-N
# 196  BRD-K51747290   hydroxyurea  VSNHCAURESNICA-UHFFFAOYSA-N
# 199  BRD-K52313696  tacedinaline  VAZAPHZUAVEOMC-UHFFFAOYSA-N
# 209  BRD-K55301415   abiraterone  GZOSMCIZMLWJML-VJLLXTKPSA-N
# 236  BRD-K63265447     docetaxel  ZDZOTLJHXYCWBA-JXHJHTFNSA-N
# 238  BRD-K63923597  azd1152-hqpa  QYZOGCMHVIGURT-UHFFFAOYSA-N
# 247  BRD-K66788707   fludarabine  HBUBKKRHXORPQB-FJFJXFQQSA-N
# 259  BRD-K70401845      imatinib  KTUFNOKKBVMGRW-UHFFFAOYSA-N
# 266  BRD-K71106091   fludarabine  HBUBKKRHXORPQB-FJFJXFQQSA-N
# 278  BRD-K76674262   hydroxyurea  VSNHCAURESNICA-UHFFFAOYSA-N
# 289  BRD-K80431395   triciribine  HOGVTUZUJGHKPL-HTVVRFAVSA-N
# 330  BRD-K92723993      imatinib  KTUFNOKKBVMGRW-UHFFFAOYSA-N
# 353         CI-994  tacedinaline  VAZAPHZUAVEOMC-UHFFFAOYSA-N
#
#                                               synonyms drugclass TTD_drug_ID  \
# 2    nsc 154020; pentaazacentopthylene; tricyclic n...  targeted      D04GSV
# 38                                         finasteride  targeted      D08IWD
# 60   tretinoin; atralin; renova; retin-a; retisol-a...  targeted      D02DGU
# 90                                              zytiga  targeted      D06CNP
# 98                           propecia; proscar; mk-906  targeted      D08IWD
# 119                                   avita; vitamin a  targeted      D0S7WX
# 141                                docetaxel; taxotere     chemo      D0O5WP
# 144                                         barasertib  targeted      D0Q7RE
# 196                                hydroxyurea; hydrea     chemo      D07CWD
# 199                       tacedinaline; acetyldinaline  targeted      D0W9NH
# 209                               abiraterone; cb-7598  targeted      D02STN
# 236                                  docecad; rp 56976     chemo      D0O5WP
# 238                                       azd1152-hqpa  targeted      D0Q7RE
# 247                                        fludarabine     chemo      D0F2XQ
# 259     sti571; erlotinib; tarceva; cp-358774; osi-774  targeted      D0AZ3C
# 266                                            fludara     chemo      D0TO2R
# 278              myelostat; homoharringtonine; synribo     chemo      D0M4XY
# 289                                        triciribine  targeted      D04GSV
# 330                          imatinib; gleevec; glivec  targeted      D0AZ3C
# 353                                             ci-994  targeted         NaN
#
#     PubChem_CID
# 2       65399.0
# 38          NaN
# 60          NaN
# 90    9821849.0
# 98          NaN
# 119         NaN
# 141    148124.0
# 144  11497983.0
# 196      3657.0
# 199      2746.0
# 209    132971.0
# 236    148124.0
# 238  16007391.0
# 247    657237.0
# 259      5291.0
# 266     30751.0
# 278    285033.0
# 289     65399.0
# 330      5291.0
# 353         NaN

# %%
merged_df = merged_df2

# %%
df = pd.read_csv(file_path, sep="\t", dtype=str)

# %%
#get the matching statistics
total_drugs = len(df)
matched_drugs = merged_df['BROAD_drug_ID'].notnull().sum()
unmatched_drugs = total_drugs - matched_drugs
matching_stats = {
    'total_drugs': total_drugs,
    'matched_drugs': matched_drugs,
    'unmatched_drugs': unmatched_drugs
}   
print(f"Total drugs: {matching_stats['total_drugs']}")
print(f"Matched drugs: {matching_stats['matched_drugs']}")
print(f"Unmatched drugs: {matching_stats['unmatched_drugs']}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/pyenv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BROAD_drug_ID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[186], line 3
#       1 #get the matching statistics
#       2 total_drugs = len(df)
# ----> 3 matched_drugs = merged_df['BROAD_drug_ID'].notnull().sum()
#       4 unmatched_drugs = total_drugs - matched_drugs
#       5 matching_stats = {
#       6     'total_drugs': total_drugs,
#       7     'matched_drugs': matched_drugs,
#       8     'unmatched_drugs': unmatched_drugs
#       9 }
#
# File /opt/anaconda3/envs/pyenv/lib/python3.11/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File /opt/anaconda3/envs/pyenv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'BROAD_drug_ID'

# %%
# calculate the percentage of matched drugs
if total_drugs > 0:
    matching_percentage = (matched_drugs / total_drugs) * 100
else:
    matching_percentage = 0.0
print(f"Matching percentage: {matching_percentage:.2f}%")
# Out:
# Matching percentage: 67.17%

# %% [markdown]
# # LINCS compound info

# %%
# now I will try to match df with a different synonyms file     /Users/tolgacorbaci/Desktop/Code/synonyms/input/compoundinfo_beta.txt
# load the new synonyms file
new_synonyms_file_path = '/Users/tolgacorbaci/Desktop/Code/synonyms/input/compoundinfo_beta.txt'
if not os.path.exists(new_synonyms_file_path):
    print(f"New synonyms file not found: {new_synonyms_file_path}")
    sys.exit(1)
new_synonyms_df = pd.read_csv(new_synonyms_file_path, sep="\t", dtype=str)

# %%
#append drug column string to synonyms column sep ;
df['synonyms'] = df['drug'] + '; ' + df['synonyms']
# explode df on synonyms column separating by ";" and add it as a new row for each synonym
df['synonyms'] = df['synonyms'].str.split(';')
df = df.explode('synonyms')
# remove leading and trailing spaces from synonyms
df['synonyms'] = df['synonyms'].str.strip()
# remove empty synonyms
df = df[df['synonyms'] != '']
# reset index
df['synonyms'] = df['synonyms'].str.lower().str.strip()
df['drug'] = df['drug'].str.lower().str.strip()


df.reset_index(drop=True, inplace=True)

#drop duplicates subset synonyms
df.drop_duplicates(subset=['synonyms'], inplace=True)
# Display the first few rows of the DataFrame
df.head()
# Out:
#          drug                     InChiKey    synonyms drugclass
# 0  nelarabine  IXOXBSCIXZEQEQ-UHTZMRCNSA-N  nelarabine     chemo
# 1  nelarabine  IXOXBSCIXZEQEQ-UHTZMRCNSA-N     arranon     chemo
# 2  nelarabine  IXOXBSCIXZEQEQ-UHTZMRCNSA-N    atriance     chemo
# 4  decitabine  XAUDJQYHKZQPEU-KVQBGUIXSA-N  decitabine  targeted
# 5  decitabine  XAUDJQYHKZQPEU-KVQBGUIXSA-N     dacogen  targeted

# %%
new_synonyms_df
# Out:
#              pert_id      cmap_name target  \
# 0      BRD-A08715367     L-theanine    NaN
# 1      BRD-A12237696   L-citrulline    NaN
# 2      BRD-A18795974  BRD-A18795974    NaN
# 3      BRD-A27924917  BRD-A27924917    NaN
# 4      BRD-A35931254  BRD-A35931254    NaN
# ...              ...            ...    ...
# 39316  BRD-K62685538    triptorelin  GNRHR
# 39317  BRD-K62221994        T-98475  GNRHR
# 39318  BRD-K53397409   benzoic-acid  RAB9A
# 39319  BRD-A62182663        YK-4279   DHX9
# 39320  BRD-A62182663        YK-4279   FLI1
#
#                                                      moa  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 39316  Gonadotropin releasing factor hormone receptor...
# 39317  Gonadotropin releasing factor hormone receptor...
# 39318  Precursor for food preservatives, plasticizers...
# 39319  Binding of RNA helicase A to the transcription...
# 39320  Binding of RNA helicase A to the transcription...
#
#                                         canonical_smiles  \
# 0                                   CCNC(=O)CCC(N)C(O)=O
# 1                                   NC(CCCNC(N)=O)C(O)=O
# 2                             CCCN(CCC)C1CCc2ccc(O)cc2C1
# 3                        NCC(O)(CS(O)(=O)=O)c1ccc(Cl)cc1
# 4                     CN1CCc2cccc-3c2C1Cc1ccc(O)c(O)c-31
# ...                                                  ...
# 39316  CC(C)C[C@H](NC(=O)[C@@H](Cc1c[nH]c2ccccc12)NC(...
# 39317  CC(C)OC(=O)c1cn(Cc2c(F)cccc2F)c3sc(c(CN(C)Cc4c...
# 39318                                     OC(=O)c1ccccc1
# 39319       COc1ccc(cc1)C(=O)CC1(O)C(=O)Nc2c1c(Cl)ccc2Cl
# 39320       COc1ccc(cc1)C(=O)CC1(O)C(=O)Nc2c1c(Cl)ccc2Cl
#
#                          inchi_key   compound_aliases
# 0      DATAGRPVKZEWHA-UHFFFAOYSA-N         l-theanine
# 1      RHGKLRLOHDJJDR-UHFFFAOYSA-N       l-citrulline
# 2      BLYMJBIZMIGWFK-UHFFFAOYSA-N     7-hydroxy-DPAT
# 3      WBSMZVIMANOCNX-UHFFFAOYSA-N  2-hydroxysaclofen
# 4      VMWNQDUVQKEIOC-UHFFFAOYSA-N   r(-)-apomorphine
# ...                            ...                ...
# 39316  VXKHXGOKWPXYNA-PGBVPBMZSA-N                NaN
# 39317  RANJJVIMTOIWIN-UHFFFAOYSA-N                NaN
# 39318  WPYMKLBDIGXBTP-UHFFFAOYSA-N                NaN
# 39319  HLXSCTYHLQHQDJ-UHFFFAOYSA-N                NaN
# 39320  HLXSCTYHLQHQDJ-UHFFFAOYSA-N                NaN
#
# [39321 rows x 7 columns]

# %%
#str lower and remove leading and trailing spaces from both columns
new_synonyms_df['cmap_name'] = new_synonyms_df['cmap_name'].str.lower().str.strip()

# %%
# match new_synonyms_df and df on synonyms column
merged_df = pd.merge(df, new_synonyms_df, left_on='synonyms', right_on='cmap_name', how='inner')
# Display the first few rows of the merged DataFrame
merged_df
# Out:
#                drug                     InChiKey    synonyms drugclass  \
# 0        nelarabine  IXOXBSCIXZEQEQ-UHTZMRCNSA-N  nelarabine     chemo
# 1        decitabine  XAUDJQYHKZQPEU-KVQBGUIXSA-N  decitabine  targeted
# 2          olaparib  FDLYAMZZIXQODN-UHFFFAOYSA-N    olaparib  targeted
# 3          olaparib  FDLYAMZZIXQODN-UHFFFAOYSA-N    olaparib  targeted
# 4        vorinostat  WAEXFXRVDQXREF-UHFFFAOYSA-N  vorinostat  targeted
# ...             ...                          ...         ...       ...
# 1581        tak-530  VWMJHAFYPMOMGF-ZCFIWIBFSA-N    mln-2480  targeted
# 1582  disulfiram+cu  AUZONCFQVSMFAP-UHFFFAOYSA-N  disulfiram  targeted
# 1583  disulfiram+cu  AUZONCFQVSMFAP-UHFFFAOYSA-N  disulfiram  targeted
# 1584  disulfiram+cu  AUZONCFQVSMFAP-UHFFFAOYSA-N  disulfiram  targeted
# 1585        erastin  BKQFRNYHFIQEKN-UHFFFAOYSA-N     erastin  targeted
#
#             pert_id   cmap_name target                               moa  \
# 0     BRD-K84466663  nelarabine    NaN                               NaN
# 1     BRD-K79254416  decitabine  DNMT1   DNA methyltransferase inhibitor
# 2     BRD-K02113016    olaparib  PARP2                    PARP inhibitor
# 3     BRD-K02113016    olaparib  PARP1                    PARP inhibitor
# 4     BRD-K81418486  vorinostat  HDAC6                    HDAC inhibitor
# ...             ...         ...    ...                               ...
# 1581  BRD-K43410529    mln-2480    NaN                               NaN
# 1582  BRD-K32744045  disulfiram  ALDH2                      TRPV agonist
# 1583  BRD-K32744045  disulfiram  ALDH2   DNA methyltransferase inhibitor
# 1584  BRD-K32744045  disulfiram  ALDH2  Aldehyde dehydrogenase inhibitor
# 1585  BRD-A25004090     erastin  VDAC2            Ion channel antagonist
#
#                                        canonical_smiles  \
# 0     COc1nc(N)nc2n(cnc12)[C@@H]1O[C@H](CO)[C@@H](O)...
# 1            Nc1ncn([C@H]2C[C@H](O)[C@@H](CO)O2)c(=O)n1
# 2     Fc1ccc(Cc2n[nH]c(=O)c3ccccc23)cc1C(=O)N1CCN(CC...
# 3     Fc1ccc(Cc2n[nH]c(=O)c3ccccc23)cc1C(=O)N1CCN(CC...
# 4                           ONC(=O)CCCCCCC(=O)Nc1ccccc1
# ...                                                 ...
# 1581  C[C@@H](NC(=O)c1ncnc(N)c1Cl)c1ncc(s1)C(=O)Nc1c...
# 1582                         CCN(CC)C(=S)SSC(=S)N(CC)CC
# 1583                         CCN(CC)C(=S)SSC(=S)N(CC)CC
# 1584                         CCN(CC)C(=S)SSC(=S)N(CC)CC
# 1585  CCOc1ccccc1-n1c(=O)c2ccccc2nc1C(C)N1CCN(CC1)C(...
#
#                         inchi_key compound_aliases
# 0     IXOXBSCIXZEQEQ-UHTZMRCNSA-N              NaN
# 1     XAUDJQYHKZQPEU-KVQBGUIXSA-N              NaN
# 2     FDLYAMZZIXQODN-UHFFFAOYSA-N              NaN
# 3     FDLYAMZZIXQODN-UHFFFAOYSA-N              NaN
# 4     WAEXFXRVDQXREF-UHFFFAOYSA-N              NaN
# ...                           ...              ...
# 1581  VWMJHAFYPMOMGF-ZCFIWIBFSA-N              NaN
# 1582  AUZONCFQVSMFAP-UHFFFAOYSA-N              NaN
# 1583  AUZONCFQVSMFAP-UHFFFAOYSA-N              NaN
# 1584  AUZONCFQVSMFAP-UHFFFAOYSA-N              NaN
# 1585  BKQFRNYHFIQEKN-UHFFFAOYSA-N              NaN
#
# [1586 rows x 11 columns]

# %%
# get unique number of pert_id
unique_pert_ids = merged_df['drug'].nunique()
print(f"Unique pert_id count: {unique_pert_ids}")
# get unique number of pert_id
# Out:
# Unique pert_id count: 306
